# %%
# import necessary libraries
import pandas as pd
from glob import glob

# %%
# sorted function is used to sort the files in order.
sales_files = sorted(glob('output*.csv'))
sales_files
# Out:
# ['output1.csv', 'output2.csv']

# %%
# %%time 
sales = pd.concat((pd.read_csv(file) for file in sales_files), ignore_index = True)
# Out:
# CPU times: user 5.02 ms, sys: 4.98 ms, total: 10 ms
# Wall time: 14.9 ms

# %%
sales
# Out:
#               BREADS & CEREALS          Portion size * per 100 grams (3.5 oz)  \
# 0          Bagel ( 1 average )          140 cals (45g)               310 cals
# 1           Biscuit digestives   86 cals (per biscuit)               480 cals
# 2                   Jaffa cake   48 cals (per biscuit)               370 cals
# 3    Bread white (thick slice)  96  cals (1 slice 40g)               240 cals
# 4      Bread wholemeal (thick)  88  cals (1 slice 40g)               220 cals
# ..                         ...                     ...                    ...
# 457                        NaN                     NaN                    NaN
# 458                        NaN                     NaN                    NaN
# 459                        NaN                     NaN                    NaN
# 460                        NaN                     NaN                    NaN
# 461                        NaN                     NaN                    NaN
#
# ...
